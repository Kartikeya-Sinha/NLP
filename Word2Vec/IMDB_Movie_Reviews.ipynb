# %%
import numpy as np
import pandas as pd

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('stopwords')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 7.4 MB/s eta 0:00:00
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim) (7.1.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 62.2 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 75.6 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 16.0 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy, gensim
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.3
#     Uninstalling scipy-1.15.3:
#       Successfully uninstalled scipy-1.15.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1

# %%
import gensim

# %% [markdown]
# #### Dataset Link: https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews

# %%
# Importing dataset
messages = pd.read_csv("IMDB Dataset.csv")

# %%
messages.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
# Function for text preprocessing
def preprocess_text(msg):
    stop_words = set(stopwords.words('english'))
    lemmatizer = WordNetLemmatizer()

    msg = msg.lower()
    msg = re.sub('[^a-z\s]', '', msg)
    # Tokenization
    tokens = word_tokenize(msg)
    # Removing stopwords
    tokens = [word for word in tokens if word not in stop_words]
    # Lemmatization
    lemmatized = [lemmatizer.lemmatize(word) for word in tokens]

    return lemmatized

# %%
# Creating the corpus
corpus = messages['review'].apply(preprocess_text).to_list()

# %%
# Training a Word2Vec model
model = gensim.models.Word2Vec(
    corpus,
    vector_size=100,
    window=5,
    min_count=2,
    sg=1
)

# %%
# Function for AvgWord2Vec
def avg_word2vec(doc):
    words = [model.wv[word] for word in doc if word in model.wv.index_to_key]
    # words is a list of row vectors
    if len(words) == 0:
        return np.zeros(model.vector_size)
    return np.mean(words, axis=0) # axis=0 gives us column wise mean

# %%
X = np.array([avg_word2vec(doc) for doc in corpus])

# %%
y = np.array(pd.get_dummies(messages['sentiment'], drop_first=True, dtype=int))

# %%
# Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=22)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegressionCV

# %%
# Model
lr = LogisticRegressionCV(
    cv=5,
    scoring='accuracy',
    random_state=22,
    max_iter=1000
)

# %%
# Fitting
lr.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegressionCV(cv=5, max_iter=1000, random_state=22, scoring='accuracy')

# %%
# Prediction
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
# Accuracy Score
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8791

# %%
# Classification Report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88      4987
#            1       0.88      0.88      0.88      5013
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %%
svc=SVC()

param_grid = [{'kernel': ['linear', 'rbf']},
              {'kernel': ['poly'], 'degree': [2, 3, 4]}]

grid_search=GridSearchCV(estimator=svc,param_grid=param_grid,cv=5,scoring='accuracy')

# %%
grid_search.fit(X_train, y_train.ravel())
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid=[{'kernel': ['linear', 'rbf']},
#                          {'degree': [2, 3, 4], 'kernel': ['poly']}],
#              scoring='accuracy')

# %%
best_model = grid_search.best_estimator_

# %%
grid_search.best_params_
# Out:
# {'degree': 4, 'kernel': 'poly'}

# %%
#Prediction
y_pred = best_model.predict(X_test)

# %%
# Accuracy Score
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8833

# %%
# Classification Report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88      4987
#            1       0.88      0.89      0.88      5013
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(
    n_estimators=150,
    max_depth=10,
    max_features='sqrt',
    random_state=22,
    n_jobs=-1
)

# %%
rf.fit(X_train, y_train.ravel())
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=150, n_jobs=-1,
#                        random_state=22)

# %%
# Prediction
y_pred = rf.predict(X_test)

# %%
# Accuracy Score
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.836

# %%
# Classification Report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.87      4987
#            1       0.87      0.87      0.87      5013
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000

# %% [markdown]
# ### XGBoost

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier(
    n_estimators=150,
    max_depth=5,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    eval_metric='logloss',
    random_state=22,
    n_jobs=-1
)

# %%
xgb.fit(X_train, y_train.ravel())
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=150,
#               n_jobs=-1, num_parallel_tree=None, random_state=22, ...)

# %%
# Prediction
y_pred = xgb.predict(X_test)

# %%
# Accuracy Score
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8691

# %%
# Classification Report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.87      4987
#            1       0.87      0.87      0.87      5013
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000

# %% [markdown]
# ### ANN

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0

# %%
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.models import Sequential

# %%
classifier = Sequential()

classifier.add(Input(shape=(100,)))
classifier.add(Dense(units=128, activation='relu'))
classifier.add(Dropout(0.3))
classifier.add(Dense(units=64, activation='relu'))
classifier.add(Dropout(0.3))
classifier.add(Dense(units=1, activation='sigmoid'))

classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model_history = classifier.fit(
    X_train, y_train,
    epochs=20,
    batch_size=16,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/20
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.7811 - loss: 0.4525 - val_accuracy: 0.8708 - val_loss: 0.3106
# Epoch 2/20
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8631 - loss: 0.3299 - val_accuracy: 0.8755 - val_loss: 0.2989
# Epoch 3/20
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8621 - loss: 0.3254 - val_accuracy: 0.8761 - val_loss: 0.3028
# Epoch 4/20
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8646 - loss: 0.3181 - val_accuracy: 0.8767 - val_loss: 0.2969
# Epoch 5/20
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8679 - loss: 0.3161 - val_accuracy: 0.8745 - val_loss: 0.3006
# Epoch 6/20
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8683 - loss: 0.3148 - val_accuracy: 0.8702 - val_loss: 0.3068
# Epoch 7/20
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8706 - loss: 0.3065 - val_accuracy: 0.8766 - val_loss: 0.2901
# Epoch 8/20
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8679 - loss: 0.3145 - val_accuracy: 0.8767 - val_loss: 0.2920
# Epoch 9/20
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8703 - loss: 0.3118 - val_accuracy: 0.8791 - val_loss: 0.2865
# Epoch 10/20
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8715 - loss: 0.3055 - val_accuracy: 0.8778 - val_loss: 0.2877
# Epoch 11/20
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8736 - loss: 0.3066 - val_accuracy: 0.8727 - val_loss: 0.3017
# Epoch 12/20
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8736 - loss: 0.3048 - val_accuracy: 0.8772 - val_loss: 0.2878
# Epoch 13/20
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8780 - loss: 0.2970 - val_accuracy: 0.8785 - val_loss: 0.2906
# Epoch 14/20
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8743 - loss: 0.3017 - val_accuracy: 0.8704 - val_loss: 0.2976
# Epoch 15/20
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8757 - loss: 0.2976 - val_accuracy: 0.8745 - val_loss: 0.2954
# Epoch 16/20
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8787 - loss: 0.2961 - val_accuracy: 0.8784 - val_loss: 0.2901
# Epoch 17/20
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8724 - loss: 0.3032 - val_accuracy: 0.8716 - val_loss: 0.3023
# Epoch 18/20
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8759 - loss: 0.2989 - val_accuracy: 0.8813 - val_loss: 0.2879
# Epoch 19/20
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8732 - loss: 0.3010 - val_accuracy: 0.8809 - val_loss: 0.2839
# Epoch 20/20
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8761 - loss: 0.2974 - val_accuracy: 0.8777 - val_loss: 0.2918

# %%
loss, accuracy = classifier.evaluate(X_test, y_test)
print("Test Accuracy:", accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8799 - loss: 0.2930
# Test Accuracy: 0.8776999711990356
