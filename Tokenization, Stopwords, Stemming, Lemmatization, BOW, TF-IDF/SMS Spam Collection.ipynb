# %%
import pandas as pd

# %%
df = pd.read_csv('SMSSpamCollection', sep='\t', header=None, names=['label', 'message'])
df.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df['label'] = df['label'].map({'ham': 0, 'spam': 1})

# %%
print("No. of rows:", df.shape[0])
# Out:
# No. of rows: 5572

# %%
# Importing required libraries
import nltk
import re
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %%
def preprocess_text(msg):
    msg = msg.lower()
    msg = re.sub('[^a-z\s]', '', msg)
    # Tokenization
    tokens = word_tokenize(msg)
    # Remove stopwords
    tokens = [word for word in tokens if word not in stop_words]
    # Stemming
    stemmed = [stemmer.stem(word) for word in tokens]
    # Lemmaization
    lemmatized = [lemmatizer.lemmatize(word) for word in tokens]
    return ' '.join(lemmatized)

# %%
df['clean_message'] = df['message'].apply(preprocess_text)

# %%
df.head()
# Out:
#   label                                            message  \
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
#
#                                        clean_message
# 0  go jurong point crazy available bugis n great ...
# 1                            ok lar joking wif u oni
# 2  free entry wkly comp win fa cup final tkts st ...
# 3                u dun say early hor u c already say
# 4           nah dont think go usf life around though

# %%
# Bag of Words
cv = CountVectorizer()
X_bow = cv.fit_transform(df['clean_message'])

# %%
cv.vocabulary_
# Out:
# {'go': 2668,
#  'jurong': 3510,
#  'point': 5129,
#  'crazy': 1455,
#  'available': 460,
#  'bugis': 887,
#  'great': 2756,
#  'world': 7698,
#  'la': 3657,
#  'buffet': 885,
#  'cine': 1192,
#  'got': 2720,
#  'amore': 233,
#  'wat': 7474,
#  'ok': 4712,
#  'lar': 3690,
#  'joking': 3480,
#  'wif': 7599,
#  'oni': 4743,
#  'free': 2467,
#  'entry': 2077,
#  'wkly': 7654,
#  'comp': 1300,
#  'win': 7612,
#  'fa': 2207,
#  'cup': 1510,
#  'final': 2320,
#  'tkts': 6939,
#  'st': 6393,
#  'may': 4097,
#  'text': 6785,
#  'receive': 5512,
#  'questionstd': 5407,
#  'txt': 7140,
#  'ratetcs': 5459,
#  'apply': 320,
#  'over': 4835,
#  'dun': 1936,
#  'say': 5837,
#  'early': 1956,
#  'hor': 3072,
#  'already': 205,
#  'nah': 4422,
#  'dont': 1851,
#  'think': 6856,
#  'usf': 7287,
#  'life': 3781,
#  'around': 367,
#  'though': 6876,
#  'freemsg': 2475,
#  'hey': 2973,
#  'darling': 1571,
#  'week': 7522,
#  'word': 7686,
#  'back': 503,
#  'id': 3183,
#  'like': 3796,
#  'fun': 2538,
#  'still': 6457,
#  'tb': 6719,
#  'xxx': 7824,
#  'std': 6433,
#  'chgs': 1140,
#  'send': 5923,
#  'rcv': 5470,
#  'even': 2123,
#  'brother': 856,
#  'speak': 6312,
#  'treat': 7071,
#  'aid': 152,
#  'patent': 4930,
#  'per': 4971,
#  'request': 5616,
#  'melle': 4137,
#  'oru': 4805,
#  'minnaminunginte': 4215,
#  'nurungu': 4644,
#  'vettam': 7350,
#  'set': 5952,
#  'callertune': 950,
#  'caller': 949,
#  'press': 5257,
#  'copy': 1399,
#  'friend': 2497,
#  'winner': 7622,
#  'valued': 7322,
#  'network': 4493,
#  'customer': 1522,
#  'selected': 5910,
#  'receivea': 5513,
#  'prize': 5289,
#  'reward': 5670,
#  'claim': 1198,
#  'call': 942,
#  'code': 1254,
#  'kl': 3618,
#  'valid': 7318,
#  'hour': 3086,
#  'mobile': 4269,
#  'month': 4303,
#  'entitled': 2074,
#  'update': 7243,
#  'latest': 3707,
#  'colour': 1276,
#  'camera': 975,
#  'co': 1243,
#  'im': 3212,
#  'gon': 2690,
#  'na': 4417,
#  'home': 3039,
#  'soon': 6268,
#  'want': 7455,
#  'talk': 6688,
#  'stuff': 6526,
#  'anymore': 286,
#  'tonight': 6997,
#  'ive': 3396,
#  'cried': 1472,
#  'enough': 2065,
#  'today': 6956,
#  'six': 6127,
#  'chance': 1083,
#  'cash': 1031,
#  'pound': 5190,
#  'csh': 1488,
#  'cost': 1411,
#  'pday': 4953,
#  'day': 1589,
#  'tsandcs': 7103,
#  'reply': 5609,
#  'hl': 3006,
#  'info': 3271,
#  'urgent': 7266,
#  'membership': 4142,
#  'jackpot': 3405,
#  'tc': 6721,
#  'wwwdbuknet': 7770,
#  'lccltd': 3724,
#  'pobox': 5112,
#  'ldnwarw': 3726,
#  'searching': 5882,
#  'right': 5682,
#  'thank': 6802,
#  'breather': 824,
#  'promise': 5323,
#  'wont': 7677,
#  'take': 6681,
#  'help': 2947,
#  'granted': 2745,
#  'fulfil': 2534,
#  'wonderful': 7675,
#  'blessing': 713,
#  'time': 6915,
#  'date': 1578,
#  'sunday': 6584,
#  'xxxmobilemovieclub': 7825,
#  'use': 7282,
#  'credit': 1463,
#  'click': 1218,
#  'wap': 7459,
#  'link': 3816,
#  'next': 4511,
#  'message': 4165,
#  'httpwap': 3115,
#  'xxxmobilemovieclubcomnqjkgighjjgcbl': 7826,
#  'oh': 4705,
#  'kim': 3587,
#  'watching': 7478,
#  'eh': 2001,
#  'remember': 5579,
#  'spell': 6328,
#  'name': 4428,
#  'yes': 7864,
#  'naughty': 4450,
#  'make': 4020,
#  'wet': 7560,
#  'fine': 2327,
#  'thats': 6816,
#  'way': 7491,
#  'feel': 2279,
#  'gota': 2721,
#  'england': 2056,
#  'macedonia': 3985,
#  'miss': 4232,
#  'goalsteam': 2671,
#  'news': 4506,
#  'ur': 7263,
#  'national': 4443,
#  'team': 6735,
#  'eg': 1994,
#  'trywales': 7102,
#  'scotland': 5861,
#  'poboxoxwwq': 5117,
#  'seriously': 5946,
#  'going': 2683,
#  'try': 7099,
#  'ha': 2825,
#  'pay': 4941,
#  'first': 2346,
#  'da': 1537,
#  'stock': 6461,
#  'comin': 1290,
#  'aft': 120,
#  'finish': 2333,
#  'lunch': 3960,
#  'str': 6486,
#  'lor': 3888,
#  'ard': 346,
#  'smth': 6208,
#  'ffffffffff': 2294,
#  'alright': 207,
#  'meet': 4124,
#  'sooner': 6270,
#  'forced': 2419,
#  'eat': 1968,
#  'slice': 6162,
#  'really': 5494,
#  'hungry': 3140,
#  'tho': 6872,
#  'suck': 6557,
#  'mark': 4055,
#  'getting': 2628,
#  'worried': 7703,
#  'know': 3625,
#  'sick': 6077,
#  'turn': 7122,
#  'pizza': 5057,
#  'lol': 3866,
#  'always': 217,
#  'convincing': 1386,
#  'catch': 1043,
#  'bus': 906,
#  'frying': 2523,
#  'egg': 1997,
#  'tea': 6730,
#  'eating': 1971,
#  'mom': 4287,
#  'left': 3746,
#  'dinner': 1766,
#  'love': 3913,
#  'amp': 235,
#  'packing': 4862,
#  'car': 1000,
#  'ill': 3208,
#  'let': 3767,
#  'there': 6836,
#  'room': 5722,
#  'ahhh': 144,
#  'work': 7691,
#  'vaguely': 7314,
#  'wait': 7429,
#  'clear': 1212,
#  'sure': 6610,
#  'sarcastic': 5813,
#  'doesnt': 1826,
#  'live': 3835,
#  'yeah': 7852,
#  'apologetic': 307,
#  'fallen': 2233,
#  'actin': 61,
#  'spoilt': 6356,
#  'child': 1156,
#  'caught': 1046,
#  'till': 6913,
#  'badly': 509,
#  'cheer': 1121,
#  'tell': 6752,
#  'anything': 292,
#  'fear': 2270,
#  'fainting': 2223,
#  'housework': 3092,
#  'quick': 5408,
#  'cuppa': 1512,
#  'thanks': 6803,
#  'subscription': 6549,
#  'ringtone': 5690,
#  'uk': 7169,
#  'charged': 1093,
#  'please': 5083,
#  'confirm': 1345,
#  'replying': 5611,
#  'yup': 7929,
#  'look': 3877,
#  'timing': 6924,
#  'msg': 4352,
#  'xuhui': 7820,
#  'learn': 3736,
#  'nd': 4456,
#  'lesson': 3766,
#  'oops': 4761,
#  'roommate': 5724,
#  'done': 1848,
#  'see': 5895,
#  'letter': 3768,
#  'decide': 1629,
#  'hello': 2940,
#  'hows': 3099,
#  'saturday': 5829,
#  'texting': 6792,
#  'youd': 7894,
#  'decided': 1630,
#  'tomo': 6982,
#  'trying': 7101,
#  'invite': 3333,
#  'pls': 5091,
#  'ahead': 142,
#  'watt': 7488,
#  'wanted': 7457,
#  'weekend': 7524,
#  'abiola': 14,
#  'forget': 2425,
#  'need': 4469,
#  'crave': 1452,
#  'sweet': 6640,
#  'arabian': 343,
#  'steed': 6440,
#  'mmmmmm': 4259,
#  'yummy': 7924,
#  'rodger': 5713,
#  'burn': 902,
#  'tried': 7079,
#  'sm': 6179,
#  'nokia': 4568,
#  'camcorder': 973,
#  'delivery': 1666,
#  'tomorrow': 6985,
#  'seeing': 5897,
#  'hope': 3063,
#  'man': 4029,
#  'well': 7538,
#  'endowed': 2048,
#  'ltgt': 3945,
#  'inch': 3240,
#  'callsmessagesmissed': 965,
#  'didnt': 1737,
#  'get': 2620,
#  'hep': 2956,
#  'immunisation': 3223,
#  'nigeria': 4524,
#  'fair': 2224,
#  'hopefully': 3067,
#  'tyler': 7151,
#  'cant': 991,
#  'could': 1421,
#  'maybe': 4099,
#  'ask': 395,
#  'bit': 690,
#  'stubborn': 6516,
#  'hospital': 3078,
#  'kept': 3562,
#  'telling': 6753,
#  'weak': 7498,
#  'sucker': 6558,
#  'thinked': 6857,
#  'saw': 5836,
#  'class': 1205,
#  'gram': 2739,
#  'usually': 7298,
#  'run': 5757,
#  'half': 2842,
#  'eighth': 2004,
#  'smarter': 6185,
#  'almost': 201,
#  'whole': 7589,
#  'second': 5886,
#  'fyi': 2551,
#  'ride': 5681,
#  'morning': 4315,
#  'he': 2906,
#  'crashing': 1451,
#  'place': 5059,
#  'wow': 7721,
#  'never': 4497,
#  'realized': 5492,
#  'embarassed': 2028,
#  'accomodations': 42,
#  'thought': 6877,
#  'liked': 3797,
#  'since': 6103,
#  'best': 647,
#  'seemed': 5901,
#  'happy': 2876,
#  'cave': 1049,
#  'sorry': 6280,
#  'give': 2650,
#  'offered': 4686,
#  'embarassing': 2029,
#  'ac': 28,
#  'sptv': 6376,
#  'new': 4501,
#  'jersey': 3448,
#  'devil': 1717,
#  'detroit': 1711,
#  'red': 5535,
#  'wing': 7620,
#  'play': 5073,
#  'ice': 3178,
#  'hockey': 3023,
#  'correct': 1404,
#  'incorrect': 3251,
#  'end': 2043,
#  'mallika': 4028,
#  'sherawat': 6003,
#  'yesterday': 7874,
#  'find': 2325,
#  'lturlgt': 3949,
#  'congrats': 1352,
#  'year': 7854,
#  'special': 6315,
#  'cinema': 1193,
#  'pas': 4918,
#  'suprman': 6608,
#  'matrix': 4086,
#  'starwars': 6422,
#  'etc': 2109,
#  'bxipwe': 925,
#  'pm': 5100,
#  'later': 3705,
#  'meeting': 4127,
#  'reached': 5476,
#  'yesgauti': 7867,
#  'sehwag': 5907,
#  'odi': 4679,
#  'series': 5944,
#  'pick': 5030,
#  'burger': 899,
#  'move': 4336,
#  'pain': 4867,
#  'killing': 3585,
#  'good': 2696,
#  'joke': 3476,
#  'girl': 2644,
#  'situation': 6124,
#  'seeker': 5898,
#  'part': 4910,
#  'checking': 1117,
#  'iq': 3347,
#  'took': 7002,
#  'forever': 2422,
#  'come': 1283,
#  'double': 1865,
#  'check': 1113,
#  'hair': 2837,
#  'dresser': 1897,
#  'said': 5781,
#  'wun': 7756,
#  'cut': 1525,
#  'short': 6042,
#  'nice': 4517,
#  'pleased': 5084,
#  'advise': 103,
#  'following': 2401,
#  'recent': 5516,
#  'review': 5668,
#  'mob': 4267,
#  'awarded': 479,
#  'bonus': 754,
#  'song': 6263,
#  'dedicated': 1639,
#  'dedicate': 1638,
#  'valuable': 7320,
#  'frnds': 2507,
#  'rply': 5736,
#  'complimentary': 1319,
#  'trip': 7080,
#  'eurodisinc': 2115,
#  'trav': 7063,
#  'acoentry': 56,
#  'dis': 1778,
#  'morefrmmob': 4312,
#  'shracomorsglsuplt': 6062,
#  'aj': 163,
#  'hear': 2917,
#  'divorce': 1806,
#  'barbie': 539,
#  'ken': 3559,
#  'plane': 5065,
#  'wah': 7422,
#  'lucky': 3953,
#  'save': 5833,
#  'money': 4293,
#  'hee': 2932,
#  'finished': 2335,
#  'hi': 2978,
#  'babe': 493,
#  'wan': 7452,
#  'something': 6249,
#  'xx': 7821,
#  'kkwhere': 3615,
#  'youhow': 7897,
#  'performed': 4978,
#  'waiting': 7433,
#  'machan': 3987,
#  'cool': 1392,
#  'gentleman': 2611,
#  'dignity': 1756,
#  'respect': 5635,
#  'people': 4970,
#  'much': 4370,
#  'shy': 6072,
#  'pa': 4857,
#  'operate': 4767,
#  'looking': 3881,
#  'job': 3463,
#  'ta': 6666,
#  'earn': 1957,
#  'ah': 140,
#  'stop': 6470,
#  'urgnt': 7270,
#  'real': 5486,
#  'yo': 7885,
#  'ticket': 6904,
#  'one': 4740,
#  'jacket': 3404,
#  'used': 7283,
#  'multis': 4381,
#  'started': 6416,
#  'came': 974,
#  'bed': 604,
#  'coin': 1259,
#  'factory': 2215,
#  'nitros': 4548,
#  'ela': 2009,
#  'kanoil': 3536,
#  'download': 1873,
#  'wen': 7544,
#  'stand': 6406,
#  'close': 1223,
#  'youll': 7901,
#  'another': 272,
#  'night': 4526,
#  'spent': 6333,
#  'late': 3700,
#  'afternoon': 122,
#  'casualty': 1041,
#  'mean': 4108,
#  'havent': 2899,
#  'stuffmoro': 6530,
#  'includes': 3244,
#  'sheet': 5999,
#  'smile': 6193,
#  'pleasure': 5086,
#  'trouble': 7085,
#  'pours': 5193,
#  'rain': 5431,
#  'sum': 6577,
#  'hurt': 3153,
#  'becoz': 602,
#  'someone': 6243,
#  'smiling': 6196,
#  'service': 5949,
#  'representative': 5614,
#  'ampm': 237,
#  'guaranteed': 2796,
#  'planning': 5070,
#  'buy': 916,
#  'lido': 3779,
#  'show': 6055,
#  'collected': 1269,
#  'simply': 6100,
#  'password': 4926,
#  'mix': 4250,
#  'verify': 7346,
#  'usher': 7289,
#  'britney': 846,
#  'fml': 2391,
#  'po': 5111,
#  'box': 788,
#  'mk': 4253,
#  'ppw': 5206,
#  'telugu': 6757,
#  'moviewat': 4339,
#  'abt': 23,
#  'load': 3847,
#  'loan': 3848,
#  'wk': 7650,
#  'hols': 3037,
#  'forgot': 2430,
#  'hairdresser': 2839,
#  'appointment': 323,
#  'four': 2448,
#  'shower': 6057,
#  'beforehand': 617,
#  'cause': 1047,
#  'prob': 5294,
#  'coffee': 1256,
#  'animation': 259,
#  'nothing': 4598,
#  'else': 2022,
#  'okay': 4713,
#  'price': 5270,
#  'long': 3873,
#  'legal': 3749,
#  'ave': 466,
#  'am': 219,
#  'gone': 2692,
#  'driving': 1905,
#  'test': 6780,
#  'yet': 7875,
#  'youre': 7907,
#  'guess': 2804,
#  'gave': 2581,
#  'boston': 775,
#  'men': 4146,
#  'changed': 1085,
#  'search': 5881,
#  'location': 3851,
#  'nyc': 4654,
#  'cuz': 1532,
#  'signin': 6088,
#  'page': 4864,
#  'umma': 7177,
#  'vava': 7333,
#  'lot': 3898,
#  'dear': 1611,
#  'wish': 7633,
#  'birthday': 688,
#  'making': 4023,
#  'truly': 7093,
#  'memorable': 4144,
#  'aight': 154,
#  'hit': 2998,
#  'would': 7717,
#  'ip': 3341,
#  'address': 80,
#  'considering': 1361,
#  'computer': 1325,
#  'isnt': 3365,
#  'minecraft': 4211,
#  'server': 5948,
#  'grumpy': 2788,
#  'old': 4730,
#  'better': 654,
#  'lying': 3976,
#  'worry': 7705,
#  'busy': 910,
#  'plural': 5096,
#  'noun': 4607,
#  'research': 5622,
#  'dinnermsg': 1767,
#  'thing': 6854,
#  'scared': 5848,
#  'mah': 4008,
#  'loud': 3908,
#  'gent': 2609,
#  'contact': 1366,
#  'last': 3697,
#  'draw': 1886,
#  'hr': 3105,
#  'ppm': 5201,
#  'wa': 7418,
#  'openin': 4765,
#  'sentence': 5936,
#  'formal': 2434,
#  'anyway': 296,
#  'juz': 3516,
#  'tt': 7108,
#  'eatin': 1970,
#  'puttin': 5385,
#  'weighthaha': 7530,
#  'anythin': 291,
#  'happened': 2868,
#  'entered': 2067,
#  'cabin': 930,
#  'bday': 589,
#  'bos': 774,
#  'felt': 2286,
#  'askd': 396,
#  'invited': 3334,
#  'apartment': 301,
#  'went': 7547,
#  'specially': 6320,
#  'holiday': 3033,
#  'flight': 2369,
#  'inc': 3239,
#  'operator': 4768,
#  'pmin': 5102,
#  'goodo': 2709,
#  'must': 4398,
#  'friday': 2493,
#  'eggpotato': 1998,
#  'ratio': 5461,
#  'tortilla': 7020,
#  'needed': 4471,
#  'hmmmy': 3019,
#  'uncle': 7186,
#  'informed': 3275,
#  'paying': 4947,
#  'school': 5854,
#  'directly': 1773,
#  'food': 2409,
#  'private': 5286,
#  'account': 46,
#  'statement': 6425,
#  'unredeemed': 7228,
#  'identifier': 3189,
#  'expires': 2187,
#  'landline': 3679,
#  'boxwrc': 795,
#  'applespairsall': 318,
#  'malarky': 4025,
#  'voda': 7398,
#  'number': 4638,
#  'ending': 2045,
#  'award': 478,
#  'match': 4077,
#  'quoting': 5419,
#  'standard': 6407,
#  'rate': 5458,
#  'app': 311,
#  'sao': 5807,
#  'mu': 4369,
#  'predict': 5232,
#  'buying': 918,
#  'knowyetunde': 3632,
#  'hasnt': 2888,
#  'sent': 5934,
#  'bother': 777,
#  'sending': 5926,
#  'involve': 3338,
#  'shouldnt': 6050,
#  'imposed': 3229,
#  'apologise': 308,
#  'del': 1656,
#  'bak': 517,
#  'lucyxx': 3957,
#  'kkhow': 3609,
#  'tmorrowpls': 6944,
#  'accomodate': 41,
#  'answer': 274,
#  'question': 5405,
#  'sunshine': 6591,
#  'quiz': 5415,
#  'top': 7011,
#  'sony': 6265,
#  'dvd': 1945,
#  'player': 5075,
#  'country': 1427,
#  'algarve': 182,
#  'ansr': 273,
#  'sptyrone': 6377,
#  'laid': 3670,
#  'dogging': 1831,
#  'direct': 1772,
#  'join': 3471,
#  'largest': 3694,
#  'bt': 870,
#  'txting': 7145,
#  'gravel': 2750,
#  'nt': 4628,
#  'eca': 1973,
#  'pmsgp': 5105,
#  'haf': 2831,
#  'msn': 4362,
#  'yijuehotmailcom': 7882,
#  'befor': 616,
#  'activity': 67,
#  'chat': 1103,
#  'svc': 6626,
#  'hardcore': 2878,
#  'age': 129,
#  'yr': 7920,
#  'lazy': 3722,
#  'type': 7152,
#  'lect': 3743,
#  'pouch': 5189,
#  'sir': 6113,
#  'mail': 4012,
#  'swt': 6654,
#  'nver': 4648,
#  'tired': 6927,
#  'little': 3834,
#  'lovable': 3912,
#  'person': 4989,
#  'cozsomtimes': 1439,
#  'occupy': 4671,
#  'biggest': 671,
#  'heart': 2921,
#  'gud': 2798,
#  'ni': 4515,
#  'open': 4762,
#  'ya': 7836,
#  'dot': 1864,
#  'whats': 7566,
#  'staff': 6397,
#  'taking': 6686,
#  'replied': 5608,
#  'randy': 5451,
#  'sexy': 5964,
#  'female': 2287,
#  'local': 3850,
#  'luv': 3966,
#  'netcollex': 4489,
#  'ltd': 3940,
#  'ummmawill': 7178,
#  'inour': 3292,
#  'begin': 622,
#  'qatar': 5392,
#  'pray': 5224,
#  'hard': 2877,
#  'ki': 3575,
#  'deleted': 1660,
#  'sindu': 6105,
#  'birla': 684,
#  'soft': 6231,
#  'wine': 7618,
#  'flowing': 2382,
#  'nevering': 4498,
#  'thk': 6864,
#  'plaza': 5081,
#  'typical': 7154,
#  'everywhere': 2139,
#  'dirt': 1775,
#  'floor': 2377,
#  'window': 7616,
#  'shirt': 6018,
#  'sometimes': 6253,
#  'mouth': 4335,
#  'dream': 1889,
#  'without': 7643,
#  'chore': 1179,
#  'joy': 3492,
#  'tv': 7126,
#  'exist': 2170,
#  'hail': 2836,
#  'mist': 4242,
#  'become': 600,
#  'aaooooright': 3,
#  'leaving': 3742,
#  'house': 3088,
#  'interview': 3321,
#  'boy': 796,
#  'meare': 4114,
#  'missing': 4236,
#  'annoncement': 265,
#  'arrange': 371,
#  'keep': 3554,
#  'safe': 5776,
#  'envy': 2081,
#  'everyone': 2133,
#  'parentsi': 4901,
#  'hand': 2851,
#  'excited': 2159,
#  'spend': 6331,
#  'bootydelious': 766,
#  'inviting': 3335,
#  'wwwsmsacubootydelious': 7790,
#  'frnd': 2506,
#  'bangbabes': 531,
#  'order': 4791,
#  'content': 1369,
#  'goto': 2725,
#  'bangb': 530,
#  'internetservice': 3320,
#  'menu': 4153,
#  'culture': 1506,
#  'module': 4281,
#  'avoid': 472,
#  'missunderstding': 4240,
#  'wit': 7639,
#  'beloved': 637,
#  'escape': 2099,
#  'fancy': 2243,
#  'bridge': 830,
#  'lager': 3669,
#  'completely': 1314,
#  'formclark': 2438,
#  'also': 211,
#  'utter': 7300,
#  'waste': 7471,
#  'axis': 486,
#  'bank': 532,
#  'hmmm': 3013,
#  'hop': 3062,
#  'muz': 4404,
#  'discus': 1790,
#  'liao': 3772,
#  'coming': 1291,
#  'bloody': 726,
#  'hell': 2938,
#  'believe': 628,
#  'surname': 6616,
#  'mr': 4345,
#  'clue': 1235,
#  'spanish': 6307,
#  'bath': 561,
#  'goodfine': 2700,
#  'youve': 7914,
#  'carlos': 1019,
#  'mall': 4027,
#  'staying': 6431,
#  'til': 6912,
#  'smoke': 6199,
#  'worth': 7711,
#  'log': 3856,
#  'spoke': 6357,
#  'maneesha': 4039,
#  'wed': 7513,
#  'satisfied': 5822,
#  'experience': 2181,
#  'toll': 6977,
#  'lifted': 3790,
#  'offer': 4685,
#  'especially': 2102,
#  'approach': 326,
#  'studying': 6524,
#  'anyways': 297,
#  'gr': 2734,
#  'trust': 7095,
#  'guy': 2817,
#  'greatbye': 2758,
#  'handsome': 2856,
#  'finding': 2326,
#  'working': 7695,
#  'towards': 7034,
#  'net': 4488,
#  'mummy': 4385,
#  'wheres': 7578,
#  'boytoy': 800,
#  'haha': 2832,
#  'awesome': 481,
#  'minute': 4223,
#  'freephone': 2479,
#  'xmas': 7814,
#  'radio': 5424,
#  'jus': 3511,
#  'bathe': 562,
#  'si': 6073,
#  'using': 7290,
#  'unique': 7213,
#  'th': 6798,
#  'august': 448,
#  'wwwareyouuniquecouk': 7759,
#  'joined': 3472,
#  'league': 3734,
#  'touch': 7029,
#  'deal': 1606,
#  'personal': 4990,
#  'finally': 2322,
#  'completed': 1313,
#  'course': 1432,
#  'however': 3097,
#  'suggest': 6571,
#  'stay': 6428,
#  'able': 16,
#  'or': 4785,
#  'every': 2128,
#  'stool': 6469,
#  'settled': 5955,
#  'wishin': 7635,
#  'mrng': 4347,
#  'hav': 2895,
#  'story': 6485,
#  'hamster': 2850,
#  'dead': 1604,
#  'tmr': 6945,
#  'orchard': 4790,
#  'mrt': 4349,
#  'kate': 3542,
#  'evening': 2124,
#  'babyjontet': 499,
#  'found': 2446,
#  'enc': 2042,
#  'buck': 879,
#  'darlin': 1570,
#  'college': 1273,
#  'refilled': 5545,
#  'successfully': 6556,
#  'inr': 3295,
#  'ltdecimalgt': 3941,
#  'keralacircle': 3564,
#  'prepaid': 5243,
#  'balance': 520,
#  'transaction': 7052,
#  'kr': 3645,
#  'goodmorning': 2703,
#  'sleeping': 6155,
#  'ga': 2552,
#  'alter': 213,
#  'dat': 1576,
#  'ericsson': 2087,
#  'oso': 4807,
#  'oredi': 4794,
#  'straight': 6487,
#  'dogg': 1829,
#  'connection': 1356,
#  'refund': 5550,
#  'bill': 673,
#  'shoot': 6033,
#  'big': 669,
#  'ready': 5484,
#  'bruv': 865,
#  'break': 817,
#  'rewarding': 5671,
#  'semester': 5919,
#  'kkgoodstudy': 3608,
#  'noe': 4558,
#  'leh': 3751,
#  'sound': 6292,
#  'heading': 2910,
#  ...}

# %%
X_bow[0].toarray()
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]], dtype=int64)

# %%
# TF-IDF
tfidf = TfidfVectorizer()
X_tfidf = tfidf.fit_transform(df['clean_message'])

# %%
tfidf.vocabulary_
# Out:
# {'go': 2668,
#  'jurong': 3510,
#  'point': 5129,
#  'crazy': 1455,
#  'available': 460,
#  'bugis': 887,
#  'great': 2756,
#  'world': 7698,
#  'la': 3657,
#  'buffet': 885,
#  'cine': 1192,
#  'got': 2720,
#  'amore': 233,
#  'wat': 7474,
#  'ok': 4712,
#  'lar': 3690,
#  'joking': 3480,
#  'wif': 7599,
#  'oni': 4743,
#  'free': 2467,
#  'entry': 2077,
#  'wkly': 7654,
#  'comp': 1300,
#  'win': 7612,
#  'fa': 2207,
#  'cup': 1510,
#  'final': 2320,
#  'tkts': 6939,
#  'st': 6393,
#  'may': 4097,
#  'text': 6785,
#  'receive': 5512,
#  'questionstd': 5407,
#  'txt': 7140,
#  'ratetcs': 5459,
#  'apply': 320,
#  'over': 4835,
#  'dun': 1936,
#  'say': 5837,
#  'early': 1956,
#  'hor': 3072,
#  'already': 205,
#  'nah': 4422,
#  'dont': 1851,
#  'think': 6856,
#  'usf': 7287,
#  'life': 3781,
#  'around': 367,
#  'though': 6876,
#  'freemsg': 2475,
#  'hey': 2973,
#  'darling': 1571,
#  'week': 7522,
#  'word': 7686,
#  'back': 503,
#  'id': 3183,
#  'like': 3796,
#  'fun': 2538,
#  'still': 6457,
#  'tb': 6719,
#  'xxx': 7824,
#  'std': 6433,
#  'chgs': 1140,
#  'send': 5923,
#  'rcv': 5470,
#  'even': 2123,
#  'brother': 856,
#  'speak': 6312,
#  'treat': 7071,
#  'aid': 152,
#  'patent': 4930,
#  'per': 4971,
#  'request': 5616,
#  'melle': 4137,
#  'oru': 4805,
#  'minnaminunginte': 4215,
#  'nurungu': 4644,
#  'vettam': 7350,
#  'set': 5952,
#  'callertune': 950,
#  'caller': 949,
#  'press': 5257,
#  'copy': 1399,
#  'friend': 2497,
#  'winner': 7622,
#  'valued': 7322,
#  'network': 4493,
#  'customer': 1522,
#  'selected': 5910,
#  'receivea': 5513,
#  'prize': 5289,
#  'reward': 5670,
#  'claim': 1198,
#  'call': 942,
#  'code': 1254,
#  'kl': 3618,
#  'valid': 7318,
#  'hour': 3086,
#  'mobile': 4269,
#  'month': 4303,
#  'entitled': 2074,
#  'update': 7243,
#  'latest': 3707,
#  'colour': 1276,
#  'camera': 975,
#  'co': 1243,
#  'im': 3212,
#  'gon': 2690,
#  'na': 4417,
#  'home': 3039,
#  'soon': 6268,
#  'want': 7455,
#  'talk': 6688,
#  'stuff': 6526,
#  'anymore': 286,
#  'tonight': 6997,
#  'ive': 3396,
#  'cried': 1472,
#  'enough': 2065,
#  'today': 6956,
#  'six': 6127,
#  'chance': 1083,
#  'cash': 1031,
#  'pound': 5190,
#  'csh': 1488,
#  'cost': 1411,
#  'pday': 4953,
#  'day': 1589,
#  'tsandcs': 7103,
#  'reply': 5609,
#  'hl': 3006,
#  'info': 3271,
#  'urgent': 7266,
#  'membership': 4142,
#  'jackpot': 3405,
#  'tc': 6721,
#  'wwwdbuknet': 7770,
#  'lccltd': 3724,
#  'pobox': 5112,
#  'ldnwarw': 3726,
#  'searching': 5882,
#  'right': 5682,
#  'thank': 6802,
#  'breather': 824,
#  'promise': 5323,
#  'wont': 7677,
#  'take': 6681,
#  'help': 2947,
#  'granted': 2745,
#  'fulfil': 2534,
#  'wonderful': 7675,
#  'blessing': 713,
#  'time': 6915,
#  'date': 1578,
#  'sunday': 6584,
#  'xxxmobilemovieclub': 7825,
#  'use': 7282,
#  'credit': 1463,
#  'click': 1218,
#  'wap': 7459,
#  'link': 3816,
#  'next': 4511,
#  'message': 4165,
#  'httpwap': 3115,
#  'xxxmobilemovieclubcomnqjkgighjjgcbl': 7826,
#  'oh': 4705,
#  'kim': 3587,
#  'watching': 7478,
#  'eh': 2001,
#  'remember': 5579,
#  'spell': 6328,
#  'name': 4428,
#  'yes': 7864,
#  'naughty': 4450,
#  'make': 4020,
#  'wet': 7560,
#  'fine': 2327,
#  'thats': 6816,
#  'way': 7491,
#  'feel': 2279,
#  'gota': 2721,
#  'england': 2056,
#  'macedonia': 3985,
#  'miss': 4232,
#  'goalsteam': 2671,
#  'news': 4506,
#  'ur': 7263,
#  'national': 4443,
#  'team': 6735,
#  'eg': 1994,
#  'trywales': 7102,
#  'scotland': 5861,
#  'poboxoxwwq': 5117,
#  'seriously': 5946,
#  'going': 2683,
#  'try': 7099,
#  'ha': 2825,
#  'pay': 4941,
#  'first': 2346,
#  'da': 1537,
#  'stock': 6461,
#  'comin': 1290,
#  'aft': 120,
#  'finish': 2333,
#  'lunch': 3960,
#  'str': 6486,
#  'lor': 3888,
#  'ard': 346,
#  'smth': 6208,
#  'ffffffffff': 2294,
#  'alright': 207,
#  'meet': 4124,
#  'sooner': 6270,
#  'forced': 2419,
#  'eat': 1968,
#  'slice': 6162,
#  'really': 5494,
#  'hungry': 3140,
#  'tho': 6872,
#  'suck': 6557,
#  'mark': 4055,
#  'getting': 2628,
#  'worried': 7703,
#  'know': 3625,
#  'sick': 6077,
#  'turn': 7122,
#  'pizza': 5057,
#  'lol': 3866,
#  'always': 217,
#  'convincing': 1386,
#  'catch': 1043,
#  'bus': 906,
#  'frying': 2523,
#  'egg': 1997,
#  'tea': 6730,
#  'eating': 1971,
#  'mom': 4287,
#  'left': 3746,
#  'dinner': 1766,
#  'love': 3913,
#  'amp': 235,
#  'packing': 4862,
#  'car': 1000,
#  'ill': 3208,
#  'let': 3767,
#  'there': 6836,
#  'room': 5722,
#  'ahhh': 144,
#  'work': 7691,
#  'vaguely': 7314,
#  'wait': 7429,
#  'clear': 1212,
#  'sure': 6610,
#  'sarcastic': 5813,
#  'doesnt': 1826,
#  'live': 3835,
#  'yeah': 7852,
#  'apologetic': 307,
#  'fallen': 2233,
#  'actin': 61,
#  'spoilt': 6356,
#  'child': 1156,
#  'caught': 1046,
#  'till': 6913,
#  'badly': 509,
#  'cheer': 1121,
#  'tell': 6752,
#  'anything': 292,
#  'fear': 2270,
#  'fainting': 2223,
#  'housework': 3092,
#  'quick': 5408,
#  'cuppa': 1512,
#  'thanks': 6803,
#  'subscription': 6549,
#  'ringtone': 5690,
#  'uk': 7169,
#  'charged': 1093,
#  'please': 5083,
#  'confirm': 1345,
#  'replying': 5611,
#  'yup': 7929,
#  'look': 3877,
#  'timing': 6924,
#  'msg': 4352,
#  'xuhui': 7820,
#  'learn': 3736,
#  'nd': 4456,
#  'lesson': 3766,
#  'oops': 4761,
#  'roommate': 5724,
#  'done': 1848,
#  'see': 5895,
#  'letter': 3768,
#  'decide': 1629,
#  'hello': 2940,
#  'hows': 3099,
#  'saturday': 5829,
#  'texting': 6792,
#  'youd': 7894,
#  'decided': 1630,
#  'tomo': 6982,
#  'trying': 7101,
#  'invite': 3333,
#  'pls': 5091,
#  'ahead': 142,
#  'watt': 7488,
#  'wanted': 7457,
#  'weekend': 7524,
#  'abiola': 14,
#  'forget': 2425,
#  'need': 4469,
#  'crave': 1452,
#  'sweet': 6640,
#  'arabian': 343,
#  'steed': 6440,
#  'mmmmmm': 4259,
#  'yummy': 7924,
#  'rodger': 5713,
#  'burn': 902,
#  'tried': 7079,
#  'sm': 6179,
#  'nokia': 4568,
#  'camcorder': 973,
#  'delivery': 1666,
#  'tomorrow': 6985,
#  'seeing': 5897,
#  'hope': 3063,
#  'man': 4029,
#  'well': 7538,
#  'endowed': 2048,
#  'ltgt': 3945,
#  'inch': 3240,
#  'callsmessagesmissed': 965,
#  'didnt': 1737,
#  'get': 2620,
#  'hep': 2956,
#  'immunisation': 3223,
#  'nigeria': 4524,
#  'fair': 2224,
#  'hopefully': 3067,
#  'tyler': 7151,
#  'cant': 991,
#  'could': 1421,
#  'maybe': 4099,
#  'ask': 395,
#  'bit': 690,
#  'stubborn': 6516,
#  'hospital': 3078,
#  'kept': 3562,
#  'telling': 6753,
#  'weak': 7498,
#  'sucker': 6558,
#  'thinked': 6857,
#  'saw': 5836,
#  'class': 1205,
#  'gram': 2739,
#  'usually': 7298,
#  'run': 5757,
#  'half': 2842,
#  'eighth': 2004,
#  'smarter': 6185,
#  'almost': 201,
#  'whole': 7589,
#  'second': 5886,
#  'fyi': 2551,
#  'ride': 5681,
#  'morning': 4315,
#  'he': 2906,
#  'crashing': 1451,
#  'place': 5059,
#  'wow': 7721,
#  'never': 4497,
#  'realized': 5492,
#  'embarassed': 2028,
#  'accomodations': 42,
#  'thought': 6877,
#  'liked': 3797,
#  'since': 6103,
#  'best': 647,
#  'seemed': 5901,
#  'happy': 2876,
#  'cave': 1049,
#  'sorry': 6280,
#  'give': 2650,
#  'offered': 4686,
#  'embarassing': 2029,
#  'ac': 28,
#  'sptv': 6376,
#  'new': 4501,
#  'jersey': 3448,
#  'devil': 1717,
#  'detroit': 1711,
#  'red': 5535,
#  'wing': 7620,
#  'play': 5073,
#  'ice': 3178,
#  'hockey': 3023,
#  'correct': 1404,
#  'incorrect': 3251,
#  'end': 2043,
#  'mallika': 4028,
#  'sherawat': 6003,
#  'yesterday': 7874,
#  'find': 2325,
#  'lturlgt': 3949,
#  'congrats': 1352,
#  'year': 7854,
#  'special': 6315,
#  'cinema': 1193,
#  'pas': 4918,
#  'suprman': 6608,
#  'matrix': 4086,
#  'starwars': 6422,
#  'etc': 2109,
#  'bxipwe': 925,
#  'pm': 5100,
#  'later': 3705,
#  'meeting': 4127,
#  'reached': 5476,
#  'yesgauti': 7867,
#  'sehwag': 5907,
#  'odi': 4679,
#  'series': 5944,
#  'pick': 5030,
#  'burger': 899,
#  'move': 4336,
#  'pain': 4867,
#  'killing': 3585,
#  'good': 2696,
#  'joke': 3476,
#  'girl': 2644,
#  'situation': 6124,
#  'seeker': 5898,
#  'part': 4910,
#  'checking': 1117,
#  'iq': 3347,
#  'took': 7002,
#  'forever': 2422,
#  'come': 1283,
#  'double': 1865,
#  'check': 1113,
#  'hair': 2837,
#  'dresser': 1897,
#  'said': 5781,
#  'wun': 7756,
#  'cut': 1525,
#  'short': 6042,
#  'nice': 4517,
#  'pleased': 5084,
#  'advise': 103,
#  'following': 2401,
#  'recent': 5516,
#  'review': 5668,
#  'mob': 4267,
#  'awarded': 479,
#  'bonus': 754,
#  'song': 6263,
#  'dedicated': 1639,
#  'dedicate': 1638,
#  'valuable': 7320,
#  'frnds': 2507,
#  'rply': 5736,
#  'complimentary': 1319,
#  'trip': 7080,
#  'eurodisinc': 2115,
#  'trav': 7063,
#  'acoentry': 56,
#  'dis': 1778,
#  'morefrmmob': 4312,
#  'shracomorsglsuplt': 6062,
#  'aj': 163,
#  'hear': 2917,
#  'divorce': 1806,
#  'barbie': 539,
#  'ken': 3559,
#  'plane': 5065,
#  'wah': 7422,
#  'lucky': 3953,
#  'save': 5833,
#  'money': 4293,
#  'hee': 2932,
#  'finished': 2335,
#  'hi': 2978,
#  'babe': 493,
#  'wan': 7452,
#  'something': 6249,
#  'xx': 7821,
#  'kkwhere': 3615,
#  'youhow': 7897,
#  'performed': 4978,
#  'waiting': 7433,
#  'machan': 3987,
#  'cool': 1392,
#  'gentleman': 2611,
#  'dignity': 1756,
#  'respect': 5635,
#  'people': 4970,
#  'much': 4370,
#  'shy': 6072,
#  'pa': 4857,
#  'operate': 4767,
#  'looking': 3881,
#  'job': 3463,
#  'ta': 6666,
#  'earn': 1957,
#  'ah': 140,
#  'stop': 6470,
#  'urgnt': 7270,
#  'real': 5486,
#  'yo': 7885,
#  'ticket': 6904,
#  'one': 4740,
#  'jacket': 3404,
#  'used': 7283,
#  'multis': 4381,
#  'started': 6416,
#  'came': 974,
#  'bed': 604,
#  'coin': 1259,
#  'factory': 2215,
#  'nitros': 4548,
#  'ela': 2009,
#  'kanoil': 3536,
#  'download': 1873,
#  'wen': 7544,
#  'stand': 6406,
#  'close': 1223,
#  'youll': 7901,
#  'another': 272,
#  'night': 4526,
#  'spent': 6333,
#  'late': 3700,
#  'afternoon': 122,
#  'casualty': 1041,
#  'mean': 4108,
#  'havent': 2899,
#  'stuffmoro': 6530,
#  'includes': 3244,
#  'sheet': 5999,
#  'smile': 6193,
#  'pleasure': 5086,
#  'trouble': 7085,
#  'pours': 5193,
#  'rain': 5431,
#  'sum': 6577,
#  'hurt': 3153,
#  'becoz': 602,
#  'someone': 6243,
#  'smiling': 6196,
#  'service': 5949,
#  'representative': 5614,
#  'ampm': 237,
#  'guaranteed': 2796,
#  'planning': 5070,
#  'buy': 916,
#  'lido': 3779,
#  'show': 6055,
#  'collected': 1269,
#  'simply': 6100,
#  'password': 4926,
#  'mix': 4250,
#  'verify': 7346,
#  'usher': 7289,
#  'britney': 846,
#  'fml': 2391,
#  'po': 5111,
#  'box': 788,
#  'mk': 4253,
#  'ppw': 5206,
#  'telugu': 6757,
#  'moviewat': 4339,
#  'abt': 23,
#  'load': 3847,
#  'loan': 3848,
#  'wk': 7650,
#  'hols': 3037,
#  'forgot': 2430,
#  'hairdresser': 2839,
#  'appointment': 323,
#  'four': 2448,
#  'shower': 6057,
#  'beforehand': 617,
#  'cause': 1047,
#  'prob': 5294,
#  'coffee': 1256,
#  'animation': 259,
#  'nothing': 4598,
#  'else': 2022,
#  'okay': 4713,
#  'price': 5270,
#  'long': 3873,
#  'legal': 3749,
#  'ave': 466,
#  'am': 219,
#  'gone': 2692,
#  'driving': 1905,
#  'test': 6780,
#  'yet': 7875,
#  'youre': 7907,
#  'guess': 2804,
#  'gave': 2581,
#  'boston': 775,
#  'men': 4146,
#  'changed': 1085,
#  'search': 5881,
#  'location': 3851,
#  'nyc': 4654,
#  'cuz': 1532,
#  'signin': 6088,
#  'page': 4864,
#  'umma': 7177,
#  'vava': 7333,
#  'lot': 3898,
#  'dear': 1611,
#  'wish': 7633,
#  'birthday': 688,
#  'making': 4023,
#  'truly': 7093,
#  'memorable': 4144,
#  'aight': 154,
#  'hit': 2998,
#  'would': 7717,
#  'ip': 3341,
#  'address': 80,
#  'considering': 1361,
#  'computer': 1325,
#  'isnt': 3365,
#  'minecraft': 4211,
#  'server': 5948,
#  'grumpy': 2788,
#  'old': 4730,
#  'better': 654,
#  'lying': 3976,
#  'worry': 7705,
#  'busy': 910,
#  'plural': 5096,
#  'noun': 4607,
#  'research': 5622,
#  'dinnermsg': 1767,
#  'thing': 6854,
#  'scared': 5848,
#  'mah': 4008,
#  'loud': 3908,
#  'gent': 2609,
#  'contact': 1366,
#  'last': 3697,
#  'draw': 1886,
#  'hr': 3105,
#  'ppm': 5201,
#  'wa': 7418,
#  'openin': 4765,
#  'sentence': 5936,
#  'formal': 2434,
#  'anyway': 296,
#  'juz': 3516,
#  'tt': 7108,
#  'eatin': 1970,
#  'puttin': 5385,
#  'weighthaha': 7530,
#  'anythin': 291,
#  'happened': 2868,
#  'entered': 2067,
#  'cabin': 930,
#  'bday': 589,
#  'bos': 774,
#  'felt': 2286,
#  'askd': 396,
#  'invited': 3334,
#  'apartment': 301,
#  'went': 7547,
#  'specially': 6320,
#  'holiday': 3033,
#  'flight': 2369,
#  'inc': 3239,
#  'operator': 4768,
#  'pmin': 5102,
#  'goodo': 2709,
#  'must': 4398,
#  'friday': 2493,
#  'eggpotato': 1998,
#  'ratio': 5461,
#  'tortilla': 7020,
#  'needed': 4471,
#  'hmmmy': 3019,
#  'uncle': 7186,
#  'informed': 3275,
#  'paying': 4947,
#  'school': 5854,
#  'directly': 1773,
#  'food': 2409,
#  'private': 5286,
#  'account': 46,
#  'statement': 6425,
#  'unredeemed': 7228,
#  'identifier': 3189,
#  'expires': 2187,
#  'landline': 3679,
#  'boxwrc': 795,
#  'applespairsall': 318,
#  'malarky': 4025,
#  'voda': 7398,
#  'number': 4638,
#  'ending': 2045,
#  'award': 478,
#  'match': 4077,
#  'quoting': 5419,
#  'standard': 6407,
#  'rate': 5458,
#  'app': 311,
#  'sao': 5807,
#  'mu': 4369,
#  'predict': 5232,
#  'buying': 918,
#  'knowyetunde': 3632,
#  'hasnt': 2888,
#  'sent': 5934,
#  'bother': 777,
#  'sending': 5926,
#  'involve': 3338,
#  'shouldnt': 6050,
#  'imposed': 3229,
#  'apologise': 308,
#  'del': 1656,
#  'bak': 517,
#  'lucyxx': 3957,
#  'kkhow': 3609,
#  'tmorrowpls': 6944,
#  'accomodate': 41,
#  'answer': 274,
#  'question': 5405,
#  'sunshine': 6591,
#  'quiz': 5415,
#  'top': 7011,
#  'sony': 6265,
#  'dvd': 1945,
#  'player': 5075,
#  'country': 1427,
#  'algarve': 182,
#  'ansr': 273,
#  'sptyrone': 6377,
#  'laid': 3670,
#  'dogging': 1831,
#  'direct': 1772,
#  'join': 3471,
#  'largest': 3694,
#  'bt': 870,
#  'txting': 7145,
#  'gravel': 2750,
#  'nt': 4628,
#  'eca': 1973,
#  'pmsgp': 5105,
#  'haf': 2831,
#  'msn': 4362,
#  'yijuehotmailcom': 7882,
#  'befor': 616,
#  'activity': 67,
#  'chat': 1103,
#  'svc': 6626,
#  'hardcore': 2878,
#  'age': 129,
#  'yr': 7920,
#  'lazy': 3722,
#  'type': 7152,
#  'lect': 3743,
#  'pouch': 5189,
#  'sir': 6113,
#  'mail': 4012,
#  'swt': 6654,
#  'nver': 4648,
#  'tired': 6927,
#  'little': 3834,
#  'lovable': 3912,
#  'person': 4989,
#  'cozsomtimes': 1439,
#  'occupy': 4671,
#  'biggest': 671,
#  'heart': 2921,
#  'gud': 2798,
#  'ni': 4515,
#  'open': 4762,
#  'ya': 7836,
#  'dot': 1864,
#  'whats': 7566,
#  'staff': 6397,
#  'taking': 6686,
#  'replied': 5608,
#  'randy': 5451,
#  'sexy': 5964,
#  'female': 2287,
#  'local': 3850,
#  'luv': 3966,
#  'netcollex': 4489,
#  'ltd': 3940,
#  'ummmawill': 7178,
#  'inour': 3292,
#  'begin': 622,
#  'qatar': 5392,
#  'pray': 5224,
#  'hard': 2877,
#  'ki': 3575,
#  'deleted': 1660,
#  'sindu': 6105,
#  'birla': 684,
#  'soft': 6231,
#  'wine': 7618,
#  'flowing': 2382,
#  'nevering': 4498,
#  'thk': 6864,
#  'plaza': 5081,
#  'typical': 7154,
#  'everywhere': 2139,
#  'dirt': 1775,
#  'floor': 2377,
#  'window': 7616,
#  'shirt': 6018,
#  'sometimes': 6253,
#  'mouth': 4335,
#  'dream': 1889,
#  'without': 7643,
#  'chore': 1179,
#  'joy': 3492,
#  'tv': 7126,
#  'exist': 2170,
#  'hail': 2836,
#  'mist': 4242,
#  'become': 600,
#  'aaooooright': 3,
#  'leaving': 3742,
#  'house': 3088,
#  'interview': 3321,
#  'boy': 796,
#  'meare': 4114,
#  'missing': 4236,
#  'annoncement': 265,
#  'arrange': 371,
#  'keep': 3554,
#  'safe': 5776,
#  'envy': 2081,
#  'everyone': 2133,
#  'parentsi': 4901,
#  'hand': 2851,
#  'excited': 2159,
#  'spend': 6331,
#  'bootydelious': 766,
#  'inviting': 3335,
#  'wwwsmsacubootydelious': 7790,
#  'frnd': 2506,
#  'bangbabes': 531,
#  'order': 4791,
#  'content': 1369,
#  'goto': 2725,
#  'bangb': 530,
#  'internetservice': 3320,
#  'menu': 4153,
#  'culture': 1506,
#  'module': 4281,
#  'avoid': 472,
#  'missunderstding': 4240,
#  'wit': 7639,
#  'beloved': 637,
#  'escape': 2099,
#  'fancy': 2243,
#  'bridge': 830,
#  'lager': 3669,
#  'completely': 1314,
#  'formclark': 2438,
#  'also': 211,
#  'utter': 7300,
#  'waste': 7471,
#  'axis': 486,
#  'bank': 532,
#  'hmmm': 3013,
#  'hop': 3062,
#  'muz': 4404,
#  'discus': 1790,
#  'liao': 3772,
#  'coming': 1291,
#  'bloody': 726,
#  'hell': 2938,
#  'believe': 628,
#  'surname': 6616,
#  'mr': 4345,
#  'clue': 1235,
#  'spanish': 6307,
#  'bath': 561,
#  'goodfine': 2700,
#  'youve': 7914,
#  'carlos': 1019,
#  'mall': 4027,
#  'staying': 6431,
#  'til': 6912,
#  'smoke': 6199,
#  'worth': 7711,
#  'log': 3856,
#  'spoke': 6357,
#  'maneesha': 4039,
#  'wed': 7513,
#  'satisfied': 5822,
#  'experience': 2181,
#  'toll': 6977,
#  'lifted': 3790,
#  'offer': 4685,
#  'especially': 2102,
#  'approach': 326,
#  'studying': 6524,
#  'anyways': 297,
#  'gr': 2734,
#  'trust': 7095,
#  'guy': 2817,
#  'greatbye': 2758,
#  'handsome': 2856,
#  'finding': 2326,
#  'working': 7695,
#  'towards': 7034,
#  'net': 4488,
#  'mummy': 4385,
#  'wheres': 7578,
#  'boytoy': 800,
#  'haha': 2832,
#  'awesome': 481,
#  'minute': 4223,
#  'freephone': 2479,
#  'xmas': 7814,
#  'radio': 5424,
#  'jus': 3511,
#  'bathe': 562,
#  'si': 6073,
#  'using': 7290,
#  'unique': 7213,
#  'th': 6798,
#  'august': 448,
#  'wwwareyouuniquecouk': 7759,
#  'joined': 3472,
#  'league': 3734,
#  'touch': 7029,
#  'deal': 1606,
#  'personal': 4990,
#  'finally': 2322,
#  'completed': 1313,
#  'course': 1432,
#  'however': 3097,
#  'suggest': 6571,
#  'stay': 6428,
#  'able': 16,
#  'or': 4785,
#  'every': 2128,
#  'stool': 6469,
#  'settled': 5955,
#  'wishin': 7635,
#  'mrng': 4347,
#  'hav': 2895,
#  'story': 6485,
#  'hamster': 2850,
#  'dead': 1604,
#  'tmr': 6945,
#  'orchard': 4790,
#  'mrt': 4349,
#  'kate': 3542,
#  'evening': 2124,
#  'babyjontet': 499,
#  'found': 2446,
#  'enc': 2042,
#  'buck': 879,
#  'darlin': 1570,
#  'college': 1273,
#  'refilled': 5545,
#  'successfully': 6556,
#  'inr': 3295,
#  'ltdecimalgt': 3941,
#  'keralacircle': 3564,
#  'prepaid': 5243,
#  'balance': 520,
#  'transaction': 7052,
#  'kr': 3645,
#  'goodmorning': 2703,
#  'sleeping': 6155,
#  'ga': 2552,
#  'alter': 213,
#  'dat': 1576,
#  'ericsson': 2087,
#  'oso': 4807,
#  'oredi': 4794,
#  'straight': 6487,
#  'dogg': 1829,
#  'connection': 1356,
#  'refund': 5550,
#  'bill': 673,
#  'shoot': 6033,
#  'big': 669,
#  'ready': 5484,
#  'bruv': 865,
#  'break': 817,
#  'rewarding': 5671,
#  'semester': 5919,
#  'kkgoodstudy': 3608,
#  'noe': 4558,
#  'leh': 3751,
#  'sound': 6292,
#  'heading': 2910,
#  ...}

# %%
X_tfidf[0].toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])
